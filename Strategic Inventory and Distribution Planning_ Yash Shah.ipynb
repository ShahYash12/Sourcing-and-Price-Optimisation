# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

path = r"/Users/yashshah/Downloads/Data/"

buying_costs   = pd.read_csv(path + "Buying_Costs.csv",   index_col=0).values
demand_data    = np.stack([pd.read_csv(path + f"Demand{k}.csv", index_col=0).values
                           for k in range(1, 6)])           # shape (5 stores, 14 days, 3 products)
shipping_costs = pd.read_csv(path + "Shipping Cost.csv", index_col=0).values

T = buying_costs.shape[0]          # (days)
P = buying_costs.shape[1]          # number of products
N = shipping_costs.shape[0]        # number of warehouses
M = shipping_costs.shape[1]        # number of stores


FIXED_ORDER_COST  = 2500
FIXED_SHIP_COST   =   800

IW = [5500, 6500, 7200]               # warehouse space capacities
IS = [  850,   600,   700, 1050, 1350] # store space capacities

inv_cost_wh = [0.10, 0.25, 0.15]         # $/unit/day in warehouse
inv_cost_st = [1.25, 2.25, 1.75]         # $/unit/day in store

size  = [2.0, 1.5, 1.0]                  # space per product unit
init_w = [550, 350, 750]                 # initial WH stock for each product (Milk, Salmon, Strawberry)

BIG_M = 20000


model = gp.Model("Perishable_Goods_Distribution")

# Continuous flows
o   = model.addVars(P, N, T, name="Order")           ##name='Order'
sh  = model.addVars(P, N, M, T, name="Ship")         ##name='Ship'
sw  = model.addVars(P, N, T, name="InvWH")           ##name='StoreWarehouse'
ss  = model.addVars(P, M, T, name="InvStore")        ##name='Store store'

# Binary flags for fixed costs
y_o  = model.addVars(N, T,          vtype=GRB.BINARY, name="IfOrder")
y_sh = model.addVars(N, M, T,       vtype=GRB.BINARY, name="IfShip")

## objective
model.setObjective(
      gp.quicksum(buying_costs[t, p] * o[p, i, t]
                   for p in range(P) for i in range(N) for t in range(T))
    + FIXED_ORDER_COST * gp.quicksum(y_o[i, t] for i in range(N) for t in range(T))
    + gp.quicksum(shipping_costs[i, j] * sh[p, i, j, t]
                   for p in range(P) for i in range(N) for j in range(M) for t in range(T))
    + FIXED_SHIP_COST  * gp.quicksum(y_sh[i, j, t] for i in range(N) for j in range(M) for t in range(T))
    + gp.quicksum(inv_cost_wh[p] * sw[p, i, t]
                   for p in range(P) for i in range(N) for t in range(T))
    + gp.quicksum(inv_cost_st[p] * ss[p, j, t]
                   for p in range(P) for j in range(M) for t in range(T)),
    GRB.MINIMIZE
)


# constraints
# 5‑1  Space capacities
model.addConstrs(gp.quicksum(size[p] * sw[p, i, t] for p in range(P)) <= IW[i]
                 for i in range(N) for t in range(T))
model.addConstrs(gp.quicksum(size[p] * ss[p, j, t] for p in range(P)) <= IS[j]
                 for j in range(M) for t in range(T))

# 5‑2  Warehouse inventory balance  (order arrives next day)
for p in range(P):
    for i in range(N):
        model.addConstr(sw[p, i, 0] ==
                        init_w[p]
                        - gp.quicksum(sh[p, i, j, 0] for j in range(M)))
        model.addConstrs(
            sw[p, i, t] ==
            sw[p, i, t-1]
            + o[p, i, t-1]                          # yesterday’s order arrives today
            - gp.quicksum(sh[p, i, j, t] for j in range(M))
            for t in range(1, T)
        )

# 5‑3  Store inventory balance  (shipments instant)
for p in range(P):
    for j in range(M):
        model.addConstr(ss[p, j, 0] ==
                        gp.quicksum(sh[p, i, j, 0] for i in range(N))
                        - demand_data[j, 0, p])
        model.addConstrs(
            ss[p, j, t] ==
            ss[p, j, t-1]
            + gp.quicksum(sh[p, i, j, t] for i in range(N))
            - demand_data[j, t, p]
            for t in range(1, T)
        )

# 5‑4  Fixed‑cost linking (Big‑M)
model.addConstrs(o[p, i, t] <= BIG_M * y_o[i, t]
                 for p in range(P) for i in range(N) for t in range(T))
model.addConstrs(gp.quicksum(sh[p, i, j, t] for p in range(P)) <= BIG_M * y_sh[i, j, t]
                 for i in range(N) for j in range(M) for t in range(T))


model.optimize()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2625267
# Academic license - for non-commercial use only - expires 2026-02-19
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 784 rows, 1344 columns and 3453 nonzeros
# Model fingerprint: 0x5956357b
# Variable types: 1092 continuous, 252 integer (252 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e-01, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 7e+03]
# Found heuristic solution: objective 336733.12500
# Presolve removed 12 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 772 rows, 1332 columns, 3429 nonzeros
# Variable types: 1083 continuous, 249 integer (249 binary)
#
# Root relaxation: objective 1.235548e+05, 970 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 123554.834    0   93 336733.125 123554.834  63.3%     -    0s
# H    0     0                    209278.04129 123554.834  41.0%     -    0s
# H    0     0                    206869.21142 160538.139  22.4%     -    0s
# H    0     0                    202607.62500 160538.139  20.8%     -    0s
# H    0     0                    200162.48550 160538.139  19.8%     -    0s
# H    0     0                    198009.50000 160538.139  18.9%     -    0s
#      0     0 160538.139    0  112 198009.500 160538.139  18.9%     -    0s
# H    0     0                    197389.50000 162484.740  17.7%     -    0s
#      0     0 162484.740    0  105 197389.500 162484.740  17.7%     -    0s
#      0     0 163349.460    0   94 197389.500 163349.460  17.2%     -    0s
#      0     0 163424.871    0   90 197389.500 163424.871  17.2%     -    0s
#      0     0 163449.690    0   90 197389.500 163449.690  17.2%     -    0s
# H    0     0                    196831.00000 166117.249  15.6%     -    0s
#      0     0 166117.249    0  123 196831.000 166117.249  15.6%     -    0s
#      0     0 166951.397    0  119 196831.000 166951.397  15.2%     -    0s
#      0     0 167345.641    0  109 196831.000 167345.641  15.0%     -    0s
#      0     0 167411.895    0  120 196831.000 167411.895  14.9%     -    0s
#      0     0 167430.489    0  122 196831.000 167430.489  14.9%     -    0s
# H    0     0                    196471.75000 168300.022  14.3%     -    0s
#      0     0 168300.022    0  121 196471.750 168300.022  14.3%     -    0s
#      0     0 168735.136    0  130 196471.750 168735.136  14.1%     -    0s
#      0     0 168874.220    0  123 196471.750 168874.220  14.0%     -    0s
#      0     0 168952.666    0  118 196471.750 168952.666  14.0%     -    0s
#      0     0 168968.585    0  109 196471.750 168968.585  14.0%     -    0s
# H    0     0                    196406.89510 169200.648  13.9%     -    0s
#      0     0 169200.648    0  111 196406.895 169200.648  13.9%     -    0s
# H    0     0                    196244.70114 169266.863  13.7%     -    0s
# H    0     0                    187781.75000 169266.863  9.86%     -    0s
# H    0     0                    187655.81250 169266.863  9.80%     -    0s
#      0     0 169266.863    0  113 187655.813 169266.863  9.80%     -    0s
#      0     0 169405.126    0  105 187655.813 169405.126  9.73%     -    0s
#      0     0 169406.970    0  105 187655.813 169406.970  9.72%     -    0s
#      0     2 169406.970    0  105 187655.813 169406.970  9.72%     -    0s
# H  331   347                    181786.72917 170899.663  5.99%   134    1s
# H  393   366                    181594.72917 171261.644  5.69%   127    1s
# H  440   423                    181302.72917 171261.644  5.54%   122    1s
# H  671   558                    180712.72917 171640.620  5.02%   117    1s
# H  774   654                    180708.72917 171640.620  5.02%   115    1s
# H  784   650                    180682.72917 171640.620  5.00%   114    1s
# H 1019   835                    180624.81250 171640.620  4.97%   104    2s
# H 1069   781                    179946.31250 171640.620  4.62%   103    2s
# H 1240   744                    179561.56250 171640.620  4.41%  97.3    2s
# H 1318   730                    179222.31250 171640.620  4.23%  99.3    2s
# H 1448   711                    178559.29808 173030.393  3.10%  97.9    2s
# H 1463   706                    178545.81250 173030.393  3.09%  97.1    2s
# H 1579   672                    178428.93750 173098.903  2.99%  99.2    2s
#   2001   943 175794.329   14  121 178428.938 173280.233  2.89%  94.8    5s
# H 2291  1008                    178090.18750 173280.233  2.70%   112    7s
# H 2295   960                    177971.68750 173280.233  2.64%   112    7s
# H 2665   998                    177699.68750 173280.233  2.49%   122    9s
#   2970   977     cutoff   18      177699.688 174131.335  2.01%   125   10s
#   5696  1122     cutoff   19      177699.688 176096.299  0.90%   125   15s
# H 6522  1088                    177534.06250 176399.836  0.64%   120   16s
# H 9132  1740                    177510.18750 176876.751  0.36%   103   18s
# H 9628  1761                    177470.18750 176946.686  0.29%   100   18s
#  12580  2299 177372.847   38   29 177470.188 177093.826  0.21%  87.1   20s
# *21833     0              65    177469.06250 177421.134  0.03%  66.0   23s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 3
#   MIR: 159
#   Flow cover: 733
#   Flow path: 314
#   Inf proof: 2
#   Network: 3
#   Relax-and-lift: 4
#
# Explored 22001 nodes (1448024 simplex iterations) in 23.54 seconds (39.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 177469 177470 177510 ... 179222
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.774690625000e+05, best bound 1.774690625000e+05, gap 0.0000%

# %%
# Define product names and colors
products = ['Milk', 'Salmon', 'Strawberry']
colors = {
    'Milk': '\033[36m',        # Teal
    'Strawberry': '\033[31m',  # Mild Red
    'Salmon': '\033[33m'       # Brown/Yellowish
}
reset = '\033[0m'

if model.status == GRB.OPTIMAL:
    order_days = []

    for t in range(T):
        print(f"\nDay {t + 1}:")

        # ───── ORDERS ─────
        print("\nORDERS:")
        placed = False
        for i in range(N):
            for p in range(P):
                q = o[p, i, t].x
                if q > 1e-6:
                    pname = f"{colors[products[p]]}{products[p]}{reset}"
                    print(f"  Order: {pname} to Warehouse {i} = {round(q, 2)}")
                    placed = True
            print()
        if not placed:
            print("  No orders placed on this day.")

        # ───── SHIPMENTS ─────
        print("\nSHIPMENTS:")
        moved = False
        for i in range(N):
            for j in range(M):
                ship_lines = []
                for p in range(P):
                    q = sh[p, i, j, t].x
                    if q > 1e-6:
                        pname = f"{colors[products[p]]}{products[p]}{reset}"
                        ship_lines.append(f"{pname} = {round(q, 2)}")
                if ship_lines:
                    moved = True
                    print(f"\nFrom Warehouse {i} to Store {j}:")
                    for ln in ship_lines:
                        print(f"  {ln}")
        if not moved:
            print("  No shipments on this day.")

        # ───── STORAGE – Warehouses ─────
        print("\nSTORAGE – Warehouses:")
        for i in range(N):
            stock = []
            for p in range(P):
                q = sw[p, i, t].x
                if q > 1e-6:
                    pname = f"{colors[products[p]]}{products[p]}{reset}"
                    stock.append(f"{pname} = {round(q, 2)}")
            if stock:
                print(f"\nWarehouse {i}:")
                for ln in stock:
                    print(f"  {ln}")

        # ───── STORAGE – Stores ─────
        print("\nSTORAGE – Stores:")
        for j in range(M):
            stock = []
            for p in range(P):
                q = ss[p, j, t].x
                if q > 1e-6:
                    pname = f"{colors[products[p]]}{products[p]}{reset}"
                    stock.append(f"{pname} = {round(q, 2)}")
            if stock:
                print(f"\nStore {j}:")
                for ln in stock:
                    print(f"  {ln}")

        if placed:
            order_days.append(t + 1)

    if order_days:
        print(f"\nOrders were placed on the following days: {', '.join(map(str, order_days))}")
    else:
        print("\nNo orders were placed on any day.")
else:
    print("Optimization did not result in an optimal solution.")
# Out:
# Day 1:
#
# ORDERS:
#   Order: Milk to Warehouse 0 = 1315.0
#   Order: Salmon to Warehouse 0 = 795.0
#   Order: Strawberry to Warehouse 0 = 3230.0
#
#
#
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 0:
#   Milk = 150.0
#   Salmon = 110.0
#   Strawberry = 300.0
#
# From Warehouse 0 to Store 2:
#   Milk = 180.0
#   Salmon = 100.0
#   Strawberry = 350.0
#
# From Warehouse 1 to Store 1:
#   Milk = 75.0
#   Salmon = 65.0
#   Strawberry = 150.0
#
# From Warehouse 1 to Store 3:
#   Milk = 325.0
#   Salmon = 185.0
#   Strawberry = 560.0
#
# From Warehouse 2 to Store 4:
#   Milk = 300.0
#   Salmon = 165.0
#   Strawberry = 450.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 220.0
#   Salmon = 140.0
#   Strawberry = 100.0
#
# Warehouse 1:
#   Milk = 150.0
#   Salmon = 100.0
#   Strawberry = 40.0
#
# Warehouse 2:
#   Milk = 250.0
#   Salmon = 185.0
#   Strawberry = 300.0
#
# STORAGE – Stores:
#
# Store 2:
#   Milk = 80.0
#   Salmon = 30.0
#   Strawberry = 150.0
#
# Store 3:
#   Milk = 145.0
#   Salmon = 60.0
#   Strawberry = 200.0
#
# Store 4:
#   Milk = 55.0
#
# Day 2:
#
# ORDERS:
#
#   Order: Milk to Warehouse 1 = 1770.0
#   Order: Salmon to Warehouse 1 = 990.0
#   Order: Strawberry to Warehouse 1 = 3220.0
#
#
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 0:
#   Milk = 270.0
#   Salmon = 110.0
#   Strawberry = 400.0
#
# From Warehouse 0 to Store 1:
#   Milk = 110.0
#   Salmon = 50.0
#   Strawberry = 240.0
#
# From Warehouse 0 to Store 4:
#   Milk = 125.0
#   Salmon = 75.0
#   Strawberry = 330.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 1030.0
#   Salmon = 700.0
#   Strawberry = 2360.0
#
# Warehouse 1:
#   Milk = 150.0
#   Salmon = 100.0
#   Strawberry = 40.0
#
# Warehouse 2:
#   Milk = 250.0
#   Salmon = 185.0
#   Strawberry = 300.0
#
# STORAGE – Stores:
#
# Store 0:
#   Milk = 150.0
#   Salmon = 60.0
#   Strawberry = 180.0
#
# Store 1:
#   Milk = 50.0
#   Salmon = 30.0
#   Strawberry = 90.0
#
# Day 3:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 1 to Store 2:
#   Milk = 160.0
#   Salmon = 95.0
#   Strawberry = 240.0
#
# From Warehouse 1 to Store 3:
#   Milk = 382.5
#   Salmon = 165.0
#   Strawberry = 520.0
#
# From Warehouse 2 to Store 4:
#   Milk = 250.0
#   Salmon = 90.0
#   Strawberry = 270.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 1030.0
#   Salmon = 700.0
#   Strawberry = 2360.0
#
# Warehouse 1:
#   Milk = 1377.5
#   Salmon = 830.0
#   Strawberry = 2500.0
#
# Warehouse 2:
#   Salmon = 95.0
#   Strawberry = 30.0
#
# STORAGE – Stores:
#
# Store 2:
#   Milk = 80.0
#   Salmon = 55.0
#   Strawberry = 120.0
#
# Store 3:
#   Milk = 202.5
#   Salmon = 95.0
#   Strawberry = 300.0
#
# Store 4:
#   Milk = 130.0
#
# Day 4:
#
# ORDERS:
#
#
#   Order: Milk to Warehouse 2 = 1975.0
#   Order: Salmon to Warehouse 2 = 1015.0
#   Order: Strawberry to Warehouse 2 = 3295.0
#
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 0:
#   Milk = 160.0
#   Salmon = 70.0
#   Strawberry = 250.0
#
# From Warehouse 0 to Store 1:
#   Milk = 170.0
#   Salmon = 50.0
#   Strawberry = 285.0
#
# From Warehouse 0 to Store 4:
#   Salmon = 100.0
#   Strawberry = 375.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 700.0
#   Salmon = 480.0
#   Strawberry = 1450.0
#
# Warehouse 1:
#   Milk = 1377.5
#   Salmon = 830.0
#   Strawberry = 2500.0
#
# Warehouse 2:
#   Salmon = 95.0
#   Strawberry = 30.0
#
# STORAGE – Stores:
#
# Store 1:
#   Milk = 90.0
#   Salmon = 10.0
#   Strawberry = 160.0
#
# Store 3:
#   Milk = 12.5
#
# Day 5:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 2:
#   Milk = 180.0
#   Salmon = 155.0
#   Strawberry = 400.0
#
# From Warehouse 1 to Store 3:
#   Milk = 187.5
#   Salmon = 100.0
#   Strawberry = 250.0
#
# From Warehouse 2 to Store 0:
#   Milk = 180.0
#   Salmon = 90.0
#   Strawberry = 230.0
#
# From Warehouse 2 to Store 4:
#   Milk = 270.0
#   Salmon = 135.0
#   Strawberry = 350.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 520.0
#   Salmon = 325.0
#   Strawberry = 1050.0
#
# Warehouse 1:
#   Milk = 1190.0
#   Salmon = 730.0
#   Strawberry = 2250.0
#
# Warehouse 2:
#   Milk = 1525.0
#   Salmon = 885.0
#   Strawberry = 2745.0
#
# STORAGE – Stores:
#
# Store 2:
#   Milk = 120.0
#   Salmon = 95.0
#   Strawberry = 270.0
#
# Day 6:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 0:
#   Milk = 200.0
#   Salmon = 130.0
#   Strawberry = 400.0
#
# From Warehouse 1 to Store 1:
#   Milk = 110.0
#   Salmon = 75.0
#   Strawberry = 200.0
#
# From Warehouse 1 to Store 3:
#   Milk = 240.0
#   Salmon = 155.0
#   Strawberry = 450.0
#
# From Warehouse 2 to Store 4:
#   Milk = 325.0
#   Salmon = 195.0
#   Strawberry = 750.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 320.0
#   Salmon = 195.0
#   Strawberry = 650.0
#
# Warehouse 1:
#   Milk = 840.0
#   Salmon = 500.0
#   Strawberry = 1600.0
#
# Warehouse 2:
#   Milk = 1200.0
#   Salmon = 690.0
#   Strawberry = 1995.0
#
# STORAGE – Stores:
#
# Day 7:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 2:
#   Milk = 140.0
#   Salmon = 90.0
#   Strawberry = 320.0
#
# From Warehouse 1 to Store 1:
#   Milk = 125.0
#   Salmon = 90.0
#   Strawberry = 240.0
#
# From Warehouse 1 to Store 3:
#   Milk = 220.0
#   Salmon = 130.0
#   Strawberry = 600.0
#
# From Warehouse 2 to Store 0:
#   Milk = 210.0
#   Salmon = 120.0
#   Strawberry = 480.0
#
# From Warehouse 2 to Store 4:
#   Milk = 300.0
#   Salmon = 180.0
#   Strawberry = 350.0
#
# STORAGE – Warehouses:
#
# Warehouse 0:
#   Milk = 180.0
#   Salmon = 105.0
#   Strawberry = 330.0
#
# Warehouse 1:
#   Milk = 495.0
#   Salmon = 280.0
#   Strawberry = 760.0
#
# Warehouse 2:
#   Milk = 690.0
#   Salmon = 390.0
#   Strawberry = 1165.0
#
# STORAGE – Stores:
#
# Day 8:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 0 to Store 2:
#   Milk = 180.0
#   Salmon = 105.0
#   Strawberry = 330.0
#
# From Warehouse 1 to Store 1:
#   Milk = 135.0
#   Salmon = 100.0
#   Strawberry = 250.0
#
# From Warehouse 1 to Store 3:
#   Milk = 360.0
#   Salmon = 180.0
#   Strawberry = 510.0
#
# From Warehouse 2 to Store 0:
#   Milk = 280.0
#   Salmon = 165.0
#   Strawberry = 480.0
#
# From Warehouse 2 to Store 4:
#   Milk = 290.0
#   Salmon = 120.0
#   Strawberry = 400.0
#
# STORAGE – Warehouses:
#
# Warehouse 2:
#   Milk = 120.0
#   Salmon = 105.0
#   Strawberry = 285.0
#
# STORAGE – Stores:
#
# Store 0:
#   Milk = 90.0
#   Salmon = 70.0
#   Strawberry = 190.0
#
# Store 1:
#   Milk = 40.0
#   Salmon = 50.0
#   Strawberry = 95.0
#
# Store 2:
#   Milk = 60.0
#   Salmon = 45.0
#   Strawberry = 120.0
#
# Store 3:
#   Milk = 100.0
#   Salmon = 70.0
#   Strawberry = 120.0
#
# Day 9:
#
# ORDERS:
#
#   Order: Milk to Warehouse 1 = 1765.0
#   Order: Salmon to Warehouse 1 = 1470.0
#   Order: Strawberry to Warehouse 1 = 3020.0
#
#   Order: Milk to Warehouse 2 = 1740.0
#   Order: Salmon to Warehouse 2 = 1510.0
#   Order: Strawberry to Warehouse 2 = 3210.0
#
#
# SHIPMENTS:
#
# From Warehouse 2 to Store 4:
#   Milk = 120.0
#   Salmon = 105.0
#   Strawberry = 285.0
#
# STORAGE – Warehouses:
#
# STORAGE – Stores:
#
# Day 10:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 1 to Store 1:
#   Milk = 130.0
#   Salmon = 50.0
#   Strawberry = 180.0
#
# From Warehouse 1 to Store 2:
#   Milk = 160.0
#   Salmon = 95.0
#   Strawberry = 235.0
#
# From Warehouse 1 to Store 3:
#   Milk = 285.0
#   Salmon = 170.0
#   Strawberry = 290.0
#
# From Warehouse 2 to Store 0:
#   Milk = 230.0
#   Salmon = 145.0
#   Strawberry = 360.0
#
# From Warehouse 2 to Store 4:
#   Milk = 133.75
#   Salmon = 100.0
#   Strawberry = 300.0
#
# STORAGE – Warehouses:
#
# Warehouse 1:
#   Milk = 1190.0
#   Salmon = 1155.0
#   Strawberry = 2315.0
#
# Warehouse 2:
#   Milk = 1376.25
#   Salmon = 1265.0
#   Strawberry = 2550.0
#
# STORAGE – Stores:
#
# Store 0:
#   Milk = 120.0
#   Salmon = 80.0
#   Strawberry = 160.0
#
# Store 1:
#   Milk = 80.0
#   Salmon = 20.0
#   Strawberry = 80.0
#
# Store 2:
#   Milk = 80.0
#   Salmon = 50.0
#   Strawberry = 100.0
#
# Store 3:
#   Milk = 145.0
#   Salmon = 90.0
#   Strawberry = 150.0
#
# Store 4:
#   Milk = 13.75
#
# Day 11:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 2 to Store 4:
#   Milk = 166.25
#   Salmon = 120.0
#   Strawberry = 240.0
#
# STORAGE – Warehouses:
#
# Warehouse 1:
#   Milk = 1190.0
#   Salmon = 1155.0
#   Strawberry = 2315.0
#
# Warehouse 2:
#   Milk = 1210.0
#   Salmon = 1145.0
#   Strawberry = 2310.0
#
# STORAGE – Stores:
#
# Day 12:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 1 to Store 1:
#   Milk = 175.0
#   Salmon = 120.0
#   Strawberry = 290.0
#
# From Warehouse 1 to Store 2:
#   Milk = 210.0
#   Salmon = 220.0
#   Strawberry = 385.0
#
# From Warehouse 1 to Store 3:
#   Milk = 155.0
#   Salmon = 170.0
#   Strawberry = 260.0
#
# From Warehouse 2 to Store 0:
#   Milk = 135.0
#   Salmon = 140.0
#   Strawberry = 240.0
#
# From Warehouse 2 to Store 4:
#   Milk = 200.0
#   Salmon = 210.0
#   Strawberry = 320.0
#
# STORAGE – Warehouses:
#
# Warehouse 1:
#   Milk = 650.0
#   Salmon = 645.0
#   Strawberry = 1380.0
#
# Warehouse 2:
#   Milk = 875.0
#   Salmon = 795.0
#   Strawberry = 1750.0
#
# STORAGE – Stores:
#
# Store 1:
#   Milk = 110.0
#   Salmon = 70.0
#   Strawberry = 170.0
#
# Store 2:
#   Milk = 120.0
#   Salmon = 110.0
#   Strawberry = 225.0
#
# Day 13:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 1 to Store 3:
#   Milk = 190.0
#   Salmon = 250.0
#   Strawberry = 400.0
#
# From Warehouse 2 to Store 0:
#   Milk = 170.0
#   Salmon = 160.0
#   Strawberry = 340.0
#
# From Warehouse 2 to Store 4:
#   Milk = 255.0
#   Salmon = 220.0
#   Strawberry = 510.0
#
# STORAGE – Warehouses:
#
# Warehouse 1:
#   Milk = 460.0
#   Salmon = 395.0
#   Strawberry = 980.0
#
# Warehouse 2:
#   Milk = 450.0
#   Salmon = 415.0
#   Strawberry = 900.0
#
# STORAGE – Stores:
#
# Day 14:
#
# ORDERS:
#
#
#
#   No orders placed on this day.
#
# SHIPMENTS:
#
# From Warehouse 1 to Store 1:
#   Milk = 100.0
#   Salmon = 95.0
#   Strawberry = 220.0
#
# From Warehouse 1 to Store 2:
#   Milk = 130.0
#   Salmon = 100.0
#   Strawberry = 280.0
#
# From Warehouse 1 to Store 3:
#   Milk = 230.0
#   Salmon = 200.0
#   Strawberry = 480.0
#
# From Warehouse 2 to Store 0:
#   Milk = 150.0
#   Salmon = 160.0
#   Strawberry = 400.0
#
# From Warehouse 2 to Store 4:
#   Milk = 300.0
#   Salmon = 255.0
#   Strawberry = 500.0
#
# STORAGE – Warehouses:
#
# STORAGE – Stores:
#
# Orders were placed on the following days: 1, 2, 4, 9

# %%
demand_data[2]
# Out:
# array([[100,  70, 200],
#        [ 80,  30, 150],
#        [ 80,  40, 120],
#        [ 80,  55, 120],
#        [ 60,  60, 130],
#        [120,  95, 270],
#        [140,  90, 320],
#        [120,  60, 210],
#        [ 60,  45, 120],
#        [ 80,  45, 135],
#        [ 80,  50, 100],
#        [ 90, 110, 160],
#        [120, 110, 225],
#        [130, 100, 280]])
